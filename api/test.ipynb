# %%
from athena_client import AthenaClient

client = AthenaClient(base_url="http://localhost:15000", api_key="LjldFR1b6JgOYUkBLqTs5j7glikaeex8bn5fgBnvlodT7Auq3VCs8V7fwsdImjgRwancvKKNbDerMDGcV7CjGg")

# %%
client.generate(app_id="b055244", query="nihao")
# Out:
# ---------------------------------------------------------------------------
# RemoteProtocolError                       Traceback (most recent call last)
# File ~/dify/api/.venv/lib/python3.10/site-packages/httpx/_transports/default.py:69, in map_httpcore_exceptions()
#      68 try:
# ---> 69     yield
#      70 except Exception as exc:
#
# File ~/dify/api/.venv/lib/python3.10/site-packages/httpx/_transports/default.py:113, in ResponseStream.__iter__(self)
#     112 with map_httpcore_exceptions():
# --> 113     for part in self._httpcore_stream:
#     114         yield part
#
# File ~/dify/api/.venv/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:367, in PoolByteStream.__iter__(self)
#     366 self.close()
# --> 367 raise exc from None
#
# File ~/dify/api/.venv/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:363, in PoolByteStream.__iter__(self)
#     362 try:
# --> 363     for part in self._stream:
#     364         yield part
#
# ...
